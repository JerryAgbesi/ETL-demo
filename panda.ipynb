# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
import requests

pd.options.display.max_rows=10

# %%
obj = pd.Series([1,-2,4,9],index=['a','b','c','d'])

obj
# Out:
# a    1
# b   -2
# c    4
# d    9
# dtype: int64

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
'year': [2000, 2001, 2002, 2001, 2002, 2003],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

dframe = pd.DataFrame(data,columns=["year","state","pop"],)

# %%
req = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

data = req.json()

data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50181',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50181/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50181/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50181/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50181',
#   'id': 1489657123,
#   'node_id': 'PR_kwDOAA0YD85FEZek',
#   'number': 50181,
#   'title': 'fix some dosctring-RT02-error',
#   'user': {'login': 'luke396',
#    'id': 77875500,
#    'node_id': 'MDQ6VXNlcjc3ODc1NTAw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77875500?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/luke396',
#    'html_url': 'https://github.com/luke396',
#    'followers_url': 'https://api.github.com/users/luke396/followers',
#    'following_url': 'https://api.github.com/users/luke396/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/luke396/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/luke396/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/luke396/subscriptions',
#    'organizations_url': 'https://api.github.com/users/luke396/orgs',
#    'repos_url': 'https://api.github.com/users/luke396/repos',
#    'events_url': 'https://api.github.com/users/luke396/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/luke396/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-12-11T08:26:24Z',
#   'updated_at': '2022-12-11T08:28:50Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50181',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50181',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50181.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50181.patch',
#    'merged_at': None},
#   'body': "- [x] some #49968 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nActually I'm not sure they're right, if someone could review and comment this, I will continue to fix the issues.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50181/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50181/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50180',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50180/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50180/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50180/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50180',
#   'id': 1489581524,
#   'node_id': 'I_kwDOAA0YD85YyTXU',
#   'number': 50180,
#   'title': ' lightfm installation problem',
#   'user': {'login': 'Abricovich',
#    'id': 95686247,
#    'node_id': 'U_kgDOBbQOZw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95686247?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Abricovich',
#    'html_url': 'https://github.com/Abricovich',
#    'followers_url': 'https://api.github.com/users/Abricovich/followers',
#    'following_url': 'https://api.github.com/users/Abricovich/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Abricovich/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Abricovich/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Abricovich/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Abricovich/orgs',
#    'repos_url': 'https://api.github.com/users/Abricovich/repos',
#    'events_url': 'https://api.github.com/users/Abricovich/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Abricovich/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 129350,
#     'node_id': 'MDU6TGFiZWwxMjkzNTA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Build',
#     'name': 'Build',
#     'color': '75507B',
#     'default': False,
#     'description': 'Library building on various platforms'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-11T07:14:51Z',
#   'updated_at': '2022-12-11T07:14:51Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Installation check\n\n- [X] I have read the [installation guide](https://pandas.pydata.org/pandas-docs/stable/getting_started/install.html#installing-pandas).\n\n\n### Platform\n\nLinux-5.15.0-56-generic-x86_64-with-glibc2.35\n\n### Installation Method\n\npip install\n\n### pandas Version\n\n-\n\n### Python Version\n\n3.10.6\n\n### Installation Logs\n\n<details>\r\n\r\nCollecting lightfm\r\n  Using cached lightfm-1.16.tar.gz (310 kB)\r\n  Preparing metadata (setup.py) ... done\r\nRequirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightfm) (1.23.5)\r\nRequirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from lightfm) (1.9.3)\r\nRequirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from lightfm) (2.28.1)\r\nRequirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from lightfm) (1.2.0)\r\nRequirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->lightfm) (2022.12.7)\r\nRequirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->lightfm) (1.26.13)\r\nRequirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->lightfm) (3.4)\r\nRequirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->lightfm) (2.1.1)\r\nRequirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->lightfm) (1.2.0)\r\nRequirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->lightfm) (3.1.0)\r\nBuilding wheels for collected packages: lightfm\r\n  Building wheel for lightfm (setup.py) ... error\r\n  error: subprocess-exited-with-error\r\n  \r\n  × python setup.py bdist_wheel did not run successfully.\r\n  │ exit code: 1\r\n  ╰─> [176 lines of output]\r\n      /usr/local/lib/python3.10/dist-packages/setuptools/dist.py:770: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead\r\n        warnings.warn(\r\n      running bdist_wheel\r\n      running build\r\n      running build_py\r\n      creating build\r\n      creating build/lib.linux-x86_64-cpython-310\r\n      creating build/lib.linux-x86_64-cpython-310/lightfm\r\n      copying lightfm/cross_validation.py -> build/lib.linux-x86_64-cpython-310/lightfm\r\n      copying lightfm/__init__.py -> build/lib.linux-x86_64-cpython-310/lightfm\r\n      copying lightfm/lightfm.py -> build/lib.linux-x86_64-cpython-310/lightfm\r\n      copying lightfm/data.py -> build/lib.linux-x86_64-cpython-310/lightfm\r\n      copying lightfm/_lightfm_fast.py -> build/lib.linux-x86_64-cpython-310/lightfm\r\n      copying lightfm/evaluation.py -> build/lib.linux-x86_64-cpython-310/lightfm\r\n      creating build/lib.linux-x86_64-cpython-310/lightfm/datasets\r\n      copying lightfm/datasets/__init__.py -> build/lib.linux-x86_64-cpython-310/lightfm/datasets\r\n      copying lightfm/datasets/movielens.py -> build/lib.linux-x86_64-cpython-310/lightfm/datasets\r\n      copying lightfm/datasets/_common.py -> build/lib.linux-x86_64-cpython-310/lightfm/datasets\r\n      copying lightfm/datasets/stackexchange.py -> build/lib.linux-x86_64-cpython-310/lightfm/datasets\r\n      copying lightfm/_lightfm_fast_no_openmp.c -> build/lib.linux-x86_64-cpython-310/lightfm\r\n      copying lightfm/_lightfm_fast_openmp.c -> build/lib.linux-x86_64-cpython-310/lightfm\r\n      running build_ext\r\n      building 'lightfm._lightfm_fast_openmp' extension\r\n      creating build/temp.linux-x86_64-cpython-310\r\n      creating build/temp.linux-x86_64-cpython-310/lightfm\r\n      x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g - ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50180/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50180/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50179',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50179/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50179/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50179/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50179',
#   'id': 1489502444,
#   'node_id': 'PR_kwDOAA0YD85FD1Ou',
#   'number': 50179,
#   'title': 'BUG: fixed issue where Index was being accessed with DatetimeIndex attribute',
#   'user': {'login': 'bilaljai',
#    'id': 55934929,
#    'node_id': 'MDQ6VXNlcjU1OTM0OTI5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55934929?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bilaljai',
#    'html_url': 'https://github.com/bilaljai',
#    'followers_url': 'https://api.github.com/users/bilaljai/followers',
#    'following_url': 'https://api.github.com/users/bilaljai/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/bilaljai/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/bilaljai/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/bilaljai/subscriptions',
#    'organizations_url': 'https://api.github.com/users/bilaljai/orgs',
#    'repos_url': 'https://api.github.com/users/bilaljai/repos',
#    'events_url': 'https://api.github.com/users/bilaljai/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/bilaljai/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-11T05:56:03Z',
#   'updated_at': '2022-12-11T05:58:36Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50179',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50179',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50179.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50179.patch',
#    'merged_at': None},
#   'body': '- [ ] Closes #49925 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nChanges: updated the dates method in pandas/tseries/holiday.py to include a check to prevent the DatetimeIndex attribute\r\nfrom being accessed by an Index object.  The bug occurs if the holidays land outside the provided date range which results in an empty DatetimeIndex object being converted to an Index object. The updated dates method now checks if the object contains elements before allowing access to a DatetimeIndex attribute because such an object will be of type Index. Furthermore, the Index object is converted back into a DatetimeIndex object. A test was added to pandas/tests/tseries/holiday/test_holiday.py to ensure that the intended behavior is occurring. \r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50179/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50179/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50178',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50178/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50178/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50178/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50178',
#   'id': 1489125708,
#   'node_id': 'PR_kwDOAA0YD85FCcfG',
#   'number': 50178,
#   'title': 'DEPR: deprecate Index.is_integer',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-10T23:37:41Z',
#   'updated_at': '2022-12-10T23:37:41Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50178',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50178',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50178.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50178.patch',
#    'merged_at': None},
#   'body': '- [ ] progress towards #50042\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50178/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50178/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50177',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50177/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50177/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50177/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50177',
#   'id': 1489123159,
#   'node_id': 'PR_kwDOAA0YD85FCb5H',
#   'number': 50177,
#   'title': 'BUG: ensure connection does not close before retrieving results from io.sql.execute.',
#   'user': {'login': 'cdcadman',
#    'id': 51368516,
#    'node_id': 'MDQ6VXNlcjUxMzY4NTE2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51368516?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cdcadman',
#    'html_url': 'https://github.com/cdcadman',
#    'followers_url': 'https://api.github.com/users/cdcadman/followers',
#    'following_url': 'https://api.github.com/users/cdcadman/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cdcadman/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cdcadman/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cdcadman/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cdcadman/orgs',
#    'repos_url': 'https://api.github.com/users/cdcadman/repos',
#    'events_url': 'https://api.github.com/users/cdcadman/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cdcadman/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-10T23:35:11Z',
#   'updated_at': '2022-12-11T04:57:52Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50177',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50177',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50177.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50177.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [X] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nThis fixes a bug which I introduced in #49531, and it builds on an open PR #49967 which fixes another bug I introduced.  This PR's bug is in the method `pandas.io.sql.execute`, which is documented in the user guide.  I updated the documentation.  I had to increase the minimum sqlalchemy version to 1.4.45, because 1.4.44 has a bug which would cause `pandas.io.sql.execute` to fail after my change.  The sqlalchemy bug was fixed in https://github.com/sqlalchemy/sqlalchemy/issues/8963.\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50177/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50177/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50176',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50176/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50176/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50176/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50176',
#   'id': 1489118936,
#   'node_id': 'PR_kwDOAA0YD85FCa6D',
#   'number': 50176,
#   'title': 'DEPR: deprecate Index.is_boolean',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-10T23:30:57Z',
#   'updated_at': '2022-12-10T23:30:57Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50176',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50176',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50176.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50176.patch',
#    'merged_at': None},
#   'body': '- [ ] progress towards #50042\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50176/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50176/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50175',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50175/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50175/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50175/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50175',
#   'id': 1489104096,
#   'node_id': 'PR_kwDOAA0YD85FCXbf',
#   'number': 50175,
#   'title': 'BUG: isetitem coercing df columns to object',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 1049312478,
#     'node_id': 'MDU6TGFiZWwxMDQ5MzEyNDc4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/DataFrame',
#     'name': 'DataFrame',
#     'color': '370f77',
#     'default': False,
#     'description': 'DataFrame data structure'},
#    {'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-10T23:16:44Z',
#   'updated_at': '2022-12-10T23:17:00Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50175',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50175',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50175.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50175.patch',
#    'merged_at': None},
#   'body': '- [x] closes #49922 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50175/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50175/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50174',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50174/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50174/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50174/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50174',
#   'id': 1489000364,
#   'node_id': 'PR_kwDOAA0YD85FB_Ps',
#   'number': 50174,
#   'title': 'Fixed issue with writing Decimal type to excel file - Issue #49598',
#   'user': {'login': 'alexanderwertman3',
#    'id': 56045351,
#    'node_id': 'MDQ6VXNlcjU2MDQ1MzUx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56045351?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alexanderwertman3',
#    'html_url': 'https://github.com/alexanderwertman3',
#    'followers_url': 'https://api.github.com/users/alexanderwertman3/followers',
#    'following_url': 'https://api.github.com/users/alexanderwertman3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/alexanderwertman3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/alexanderwertman3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/alexanderwertman3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/alexanderwertman3/orgs',
#    'repos_url': 'https://api.github.com/users/alexanderwertman3/repos',
#    'events_url': 'https://api.github.com/users/alexanderwertman3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/alexanderwertman3/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-10T21:40:02Z',
#   'updated_at': '2022-12-10T21:40:02Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50174',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50174',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50174.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50174.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #49598  (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50174/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50174/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50173',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50173/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50173/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50173/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50173',
#   'id': 1488974843,
#   'node_id': 'PR_kwDOAA0YD85FB5S1',
#   'number': 50173,
#   'title': 'BUG: df.setitem raising for ea bool df indexer',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 1049312478,
#     'node_id': 'MDU6TGFiZWwxMDQ5MzEyNDc4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/DataFrame',
#     'name': 'DataFrame',
#     'color': '370f77',
#     'default': False,
#     'description': 'DataFrame data structure'},
#    {'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-10T21:16:12Z',
#   'updated_at': '2022-12-10T21:16:12Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50173',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50173',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50173.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50173.patch',
#    'merged_at': None},
#   'body': '- [x] closes #47125 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50173/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50173/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50171',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50171/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50171/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50171/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50171',
#   'id': 1488953048,
#   'node_id': 'PR_kwDOAA0YD85FB0MZ',
#   'number': 50171,
#   'title': 'BUG: iloc raising for ea series',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-10T20:55:32Z',
#   'updated_at': '2022-12-11T10:04:43Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50171',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50171',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50171.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50171.patch',
#    'merged_at': None},
#   'body': '- [x] closes #49521 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50171/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50171/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50170',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50170/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50170/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50170/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50170',
#   'id': 1488944244,
#   'node_id': 'PR_kwDOAA0YD85FByIq',
#   'number': 50170,
#   'title': 'BUG: loc for ea index raising with oob slice end',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 1218227310,
#     'node_id': 'MDU6TGFiZWwxMjE4MjI3MzEw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Index',
#     'name': 'Index',
#     'color': 'e99695',
#     'default': False,
#     'description': 'Related to the Index class or subclasses'},
#    {'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-10T20:47:19Z',
#   'updated_at': '2022-12-10T20:47:28Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50170',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50170',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50170.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50170.patch',
#    'merged_at': None},
#   'body': '- [x] closes #50161 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50170/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50170/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50169',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50169/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50169/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50169/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50169',
#   'id': 1488901896,
#   'node_id': 'PR_kwDOAA0YD85FBoP5',
#   'number': 50169,
#   'title': 'Document generating compile_commands.json for C extensions',
#   'user': {'login': 'WillAyd',
#    'id': 609873,
#    'node_id': 'MDQ6VXNlcjYwOTg3Mw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/609873?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WillAyd',
#    'html_url': 'https://github.com/WillAyd',
#    'followers_url': 'https://api.github.com/users/WillAyd/followers',
#    'following_url': 'https://api.github.com/users/WillAyd/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/WillAyd/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/WillAyd/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/WillAyd/subscriptions',
#    'organizations_url': 'https://api.github.com/users/WillAyd/orgs',
#    'repos_url': 'https://api.github.com/users/WillAyd/repos',
#    'events_url': 'https://api.github.com/users/WillAyd/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/WillAyd/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-10T20:06:40Z',
#   'updated_at': '2022-12-10T20:06:40Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50169',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50169',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50169.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50169.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50169/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50169/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50166',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50166/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50166/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50166/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50166',
#   'id': 1488515984,
#   'node_id': 'I_kwDOAA0YD85YuPOQ',
#   'number': 50166,
#   'title': "BUG: reindex __cinit__() got multiple values for keyword argument 'verify_integrity'",
#   'user': {'login': 'Trackingerror',
#    'id': 103377869,
#    'node_id': 'U_kgDOBilrzQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103377869?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Trackingerror',
#    'html_url': 'https://github.com/Trackingerror',
#    'followers_url': 'https://api.github.com/users/Trackingerror/followers',
#    'following_url': 'https://api.github.com/users/Trackingerror/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Trackingerror/gists{/gist_id}',
# ...
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50148',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50148',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50148.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50148.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46267 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\n```\r\n       before           after         ratio\r\n     [a047fb6c]       [e8c3a52a]\r\n-      1.16±0.01s         962±10μs     0.00  indexing.Setitem.time_setitem_list\r\n-         382±7ms         302±10μs     0.00  indexing.Setitem.time_setitem\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50148/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50148/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50147',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50147/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50147/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50147/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50147',
#   'id': 1486544837,
#   'node_id': 'PR_kwDOAA0YD85E5PyM',
#   'number': 50147,
#   'title': 'BUG: keep value types when calling .items() on Series',
#   'user': {'login': 'Kerybas',
#    'id': 42703200,
#    'node_id': 'MDQ6VXNlcjQyNzAzMjAw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42703200?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kerybas',
#    'html_url': 'https://github.com/Kerybas',
#    'followers_url': 'https://api.github.com/users/Kerybas/followers',
#    'following_url': 'https://api.github.com/users/Kerybas/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Kerybas/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Kerybas/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Kerybas/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Kerybas/orgs',
#    'repos_url': 'https://api.github.com/users/Kerybas/repos',
#    'events_url': 'https://api.github.com/users/Kerybas/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Kerybas/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2022-12-09T10:58:26Z',
#   'updated_at': '2022-12-09T13:48:15Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50147',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50147',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50147.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50147.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #50125\r\n- [ ] closes #25969\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\nI have identified that the `.items()` method of `Series` modifies the type of values, before returning them.  \r\nOne of the major consequences (for me) is that the `.to_dict()` method unexpectedly returns modified types.  \r\nThis can be problematic with `float32` or `float16` types, as `.items()` would convert them to Python's float, thus changing the actual value of the output by adding some extra decimal digits.\r\n\r\n`.items()` modifies the type because it calls the `.__iter__()` method of the parent's class `base.IndexOpsMixin`, which [enforces the return of Python types](https://github.com/pandas-dev/pandas/blob/d1d8b666abdb03700703a39d6f9b48c5638d4d62/pandas/core/base.py#L750).\r\n\r\nFrom my point, `.items()` and `.to_dict()` should not change the type of the values. This can be easily done by refering to `Series._values`, as proposed in this PR.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50147/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50147/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50145',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50145/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50145/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50145/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50145',
#   'id': 1486402080,
#   'node_id': 'PR_kwDOAA0YD85E4wIL',
#   'number': 50145,
#   'title': 'DOC restructure contributing environment guide',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-12-09T09:23:28Z',
#   'updated_at': '2022-12-09T09:29:49Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50145',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50145',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50145.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50145.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #50134 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nHey @noatamir , thoughts on this? I think it's clearer to split it up into 3 steps:\r\n\r\n![image](https://user-images.githubusercontent.com/33491632/206668601-02e3dfb7-0d3e-4093-8654-f295535e03ff.png)\r\n\r\nI've also removed some parts which are arguably unnecessary",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50145/reactions',
#    'total_count': 1,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 1,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50145/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50143',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50143/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50143/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50143/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50143',
#   'id': 1486329126,
#   'node_id': 'I_kwDOAA0YD85Yl5Um',
#   'number': 50143,
#   'title': 'BUG: Error concatenating timezone-aware datetime column and object column containing only None',
#   'user': {'login': 'getuem',
#    'id': 50838995,
#    'node_id': 'MDQ6VXNlcjUwODM4OTk1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50838995?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/getuem',
#    'html_url': 'https://github.com/getuem',
#    'followers_url': 'https://api.github.com/users/getuem/followers',
#    'following_url': 'https://api.github.com/users/getuem/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/getuem/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/getuem/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/getuem/subscriptions',
#    'organizations_url': 'https://api.github.com/users/getuem/orgs',
#    'repos_url': 'https://api.github.com/users/getuem/repos',
#    'events_url': 'https://api.github.com/users/getuem/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/getuem/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-09T08:38:54Z',
#   'updated_at': '2022-12-09T08:53:06Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\nimport pytz\r\nfrom datetime import datetime\r\n\r\ndf1 = pd.DataFrame([{\'date\': datetime(2022, 12, 1, 12, 0, 0, 0, pytz.UTC)}])\r\ndf2 = pd.DataFrame([{\'date\': None}])\r\npd.concat([df1, df2])\r\n```\r\n\r\n### Traceback\r\n\r\n<details>\r\n\r\n```python-traceback\r\n\r\n---------------------------------------------------------------------------\r\nAttributeError                            Traceback (most recent call last)\r\nInput In [55], in <cell line: 3>()\r\n      1 df1 = pd.DataFrame([{\'date\': datetime(2022, 12, 1, 12, 0, 0, 0, pytz.UTC)}])\r\n      2 df2 = pd.DataFrame([{\'date\': None}])\r\n----> 3 pd.concat([df1, df2])\r\n\r\nFile ~/software/mambaforge/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)\r\n    325 if len(args) > num_allow_args:\r\n    326     warnings.warn(\r\n    327         msg.format(arguments=_format_argument_list(allow_args)),\r\n    328         FutureWarning,\r\n    329         stacklevel=find_stack_level(),\r\n    330     )\r\n--> 331 return func(*args, **kwargs)\r\n\r\nFile ~/software/mambaforge/envs/dev/lib/python3.10/site-packages/pandas/core/reshape/concat.py:381, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)\r\n    159 """\r\n    160 Concatenate pandas objects along a particular axis.\r\n    161 \r\n   (...)\r\n    366 1   3   4\r\n    367 """\r\n    368 op = _Concatenator(\r\n    369     objs,\r\n    370     axis=axis,\r\n   (...)\r\n    378     sort=sort,\r\n    379 )\r\n--> 381 return op.get_result()\r\n\r\nFile ~/software/mambaforge/envs/dev/lib/python3.10/site-packages/pandas/core/reshape/concat.py:616, in _Concatenator.get_result(self)\r\n    612             indexers[ax] = obj_labels.get_indexer(new_labels)\r\n    614     mgrs_indexers.append((obj._mgr, indexers))\r\n--> 616 new_data = concatenate_managers(\r\n    617     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy\r\n    618 )\r\n    619 if not self.copy:\r\n    620     new_data._consolidate_inplace()\r\n\r\nFile ~/software/mambaforge/envs/dev/lib/python3.10/site-packages/pandas/core/internals/concat.py:233, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)\r\n    231     fastpath = blk.values.dtype == values.dtype\r\n    232 else:\r\n--> 233     values = _concatenate_join_units(join_units, concat_axis, copy=copy)\r\n    234     fastpath = False\r\n    236 if fastpath:\r\n\r\nFile ~/software/mambaforge/envs/dev/lib/python3.10/site-packages/pandas/core/internals/concat.py:542, in _concatenate_join_units(join_units, concat_axis, copy)\r\n    539 has_none_blocks = any(unit.block.dtype.kind == "V" for unit in join_units)\r\n    540 upcasted_na = _dtype_to_na_value(empty_dtype, has_none_blocks)\r\n--> 542 to_concat = [\r\n    543     ju.get_reindexed_values(empty_dtype=empty_dtype, upcasted_na=upcasted_na)\r\n    544     for ju in join_units\r\n    545 ]\r\n    547 if len(to_concat) == 1:\r\n    548     # Only one block, nothing to concatenate.\r\n    549     concat_values = to_concat[0]\r\n\r\nFile ~/software/mambaforge/envs/dev/lib/python3.10/site-packages/pandas/core/internals/concat.py:543, in <listcomp>(.0)\r\n    539 has_none_blocks = any(unit.block.dtype.kind == "V" for unit in join_units)\r\n    540 upcasted_na = _dtype_to_na_value(empty_dtype, has_none_blocks)\r\n    542 to_concat = [\r\n--> 543     ju.get_reindexed_values(empty_dtype=empty_dtype, upcasted_na=upcasted_na)\r\n    544     for ju in join_units\r\n    545 ]\r\n    547 if len(to_ ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50143/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50143/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
for i in range(len(data)):
    print(data[i]['title'])
# Out:
# fix some dosctring-RT02-error
#  lightfm installation problem
# BUG: fixed issue where Index was being accessed with DatetimeIndex attribute
# DEPR: deprecate Index.is_integer
# BUG: ensure connection does not close before retrieving results from io.sql.execute.
# DEPR: deprecate Index.is_boolean
# BUG: isetitem coercing df columns to object
# Fixed issue with writing Decimal type to excel file - Issue #49598
# BUG: df.setitem raising for ea bool df indexer
# BUG: iloc raising for ea series
# BUG: loc for ea index raising with oob slice end
# Document generating compile_commands.json for C extensions
# BUG: reindex __cinit__() got multiple values for keyword argument 'verify_integrity'
# BUG: loc raising error for MultiIndex with bool indexer _and first level of object dtype_
# TYP #37715: Fix mypy errors in column.py
# BUG: Deprecation warning for bool/numeric concatenation seems too broadly scoped
# BUG: In master, math with periodindex + index of offset produces wrong result
# BUG: `Series` slicing can fail for extension array `Index`
# Test ruff for linting
# CI: remove aiobotocore pin
# DEV: remove downstream test packages from environment.yml
# TST: Added test for groupby dropping NA when grouping on columns
# BUG: displaying NaN in complex numbers does not work
# BUG: displaying string dtypes not showing storage option
# ENH: improve error reporting for dup columns in merge_asof
# PERF: Speed up Period construction
# PERF: Split blocks in blk.delete
# BUG: keep value types when calling .items() on Series
# DOC restructure contributing environment guide
# BUG: Error concatenating timezone-aware datetime column and object column containing only None
